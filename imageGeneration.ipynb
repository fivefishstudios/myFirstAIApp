# %%
import os
import openai
import requests 
from PIL import Image 
from io import BytesIO 
from IPython.display import display

openai.api_key_path = ".api-key"

# %%
prompt=""" 
realistic moody photo of an electronics engineer working on breadboard, with oscilloscope and computer behind him
"""

# %%
response = openai.Image.create(
  prompt=prompt,
  n=2,
  # size="1024x1024"
  size="512x512"
)

# %%
for url in response['data']:
    image_url = url['url']
    # print(image_url)
    httpResponse = requests.get(image_url)
    img = Image.open(BytesIO(httpResponse.content))
    # img.show()
    display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD8F870AE90>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD8F870A770>

# %%
# response
