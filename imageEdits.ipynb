# %%
import os
import openai
import requests 
from PIL import Image 
from io import BytesIO 
from IPython.display import display

openai.api_key_path = ".api-key"

# %%
prompt=""" 
a crying man surrounded by different muppet characters also looking sad
"""

# %%
response = openai.Image.create_edit(
  image=open("./images/cry.png", "rb"),
  prompt=prompt,
  n=2,
  # size="1024x1024"
  size="512x512"
)

# %%
for url in response['data']:
    image_url = url['url']
    # print(image_url)
    httpResponse = requests.get(image_url)
    img = Image.open(BytesIO(httpResponse.content))
    # img.show()
    display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD080516EF0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD080846620>

# %%
# response
